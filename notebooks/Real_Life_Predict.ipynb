# %%
import numpy as np
import pandas as pd
import pickle

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv("world_bank_data_2025.csv")

# %%
pd.options.display.float_format="{:,.6f}".format

# %%
df[(df["country_name"]=="Turkiye")&(df["year"]==2023)]
# Out:
#      country_name country_id  year  Inflation (CPI %)  \
# 3165      Turkiye         tr  2023          53.859409
#
#             GDP (Current USD)  GDP per Capita (Current USD)  \
# 3165 1,118,252,964,260.770020                 13,105.658568
#
#       Unemployment Rate (%)  Interest Rate (Real, %)  \
# 3165               9.388000                      NaN
#
#       Inflation (GDP Deflator, %)  GDP Growth (% Annual)  \
# 3165                    68.233934               5.111168
#
#       Current Account Balance (% GDP)  Government Expense (% of GDP)  \
# 3165                        -3.566009                      33.706763
#
#       Government Revenue (% of GDP)  Tax Revenue (% of GDP)  \
# 3165                      29.350305               18.535407
#
#       Gross National Income (USD)  Public Debt (% of GDP)
# 3165     1,107,012,964,203.479980               33.107223

# %%
with open("gdp_growth_model.pkl","rb") as f :
    pipeline=pickle.load(f)

# %%
df_2=df[(df["country_name"]=="Turkiye")&(df["year"]==2023)]

# %%
df_2["Interest Rate (Real, %)"]=35

# %%
# I search on google and ı get ınterest rate of Turkiye in 2023.

# %%
df_2
# Out:
#      country_name country_id  year  Inflation (CPI %)  \
# 3165      Turkiye         tr  2023          53.859409
#
#             GDP (Current USD)  GDP per Capita (Current USD)  \
# 3165 1,118,252,964,260.770020                 13,105.658568
#
#       Unemployment Rate (%)  Interest Rate (Real, %)  \
# 3165               9.388000                       35
#
#       Inflation (GDP Deflator, %)  GDP Growth (% Annual)  \
# 3165                    68.233934               5.111168
#
#       Current Account Balance (% GDP)  Government Expense (% of GDP)  \
# 3165                        -3.566009                      33.706763
#
#       Government Revenue (% of GDP)  Tax Revenue (% of GDP)  \
# 3165                      29.350305               18.535407
#
#       Gross National Income (USD)  Public Debt (% of GDP)
# 3165     1,107,012,964,203.479980               33.107223

# %%
df_2.columns
# Out:
# Index(['country_name', 'country_id', 'year', 'Inflation (CPI %)',
#        'GDP (Current USD)', 'GDP per Capita (Current USD)',
#        'Unemployment Rate (%)', 'Interest Rate (Real, %)',
#        'Inflation (GDP Deflator, %)', 'GDP Growth (% Annual)',
#        'Current Account Balance (% GDP)', 'Government Expense (% of GDP)',
#        'Government Revenue (% of GDP)', 'Tax Revenue (% of GDP)',
#        'Gross National Income (USD)', 'Public Debt (% of GDP)'],
#       dtype='object')

# %%
df_2_drop=df_2.drop(labels=["country_name","country_id","year","Inflation (CPI %)","GDP (Current USD)","GDP per Capita (Current USD)","GDP Growth (% Annual)","Government Expense (% of GDP)","Government Revenue (% of GDP)","Tax Revenue (% of GDP)","Gross National Income (USD)","Public Debt (% of GDP)"],axis=1)

# %%
df_2_drop
# Out:
#       Unemployment Rate (%)  Interest Rate (Real, %)  \
# 3165               9.388000                       35
#
#       Inflation (GDP Deflator, %)  Current Account Balance (% GDP)
# 3165                    68.233934                        -3.566009

# %%
print("Real GDP Growth:",df_2["GDP Growth (% Annual)"].iloc[0])
print("Prediction of Model GDP Growth:",pipeline.predict(df_2_drop)[0])
# Out:
# Real GDP Growth: 5.11116818488702
# Prediction of Model GDP Growth: 3.6769995948190255

# %%
# Real GDP Growtf of Turkiye in 2023 was 5.11.
# My prediction of my model is 3.68.
#There is 1.43 failure point this is not bad beacuse our model consist of four component which are Unemployemnt Rate,Interest Rate,Inflation and Current Account Balance.
# In addittion Macrodata has not investment variables it is big problem to calculate GDP Growth.
#So we can say for 1.43 failure point is about change in politics,tastes,fashion,trends and lack of investment variables.
#These phenomenons like taste or trends and others can not calculate very well,it is more about human psychology moreover impact of these features in consumption and GDP Growth is important.
#Nevertheless my model has 1.43 failure point in 2023 is not bad if we think discussed situations
